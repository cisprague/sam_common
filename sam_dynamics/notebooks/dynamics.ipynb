# %%
from sympy import *
init_printing()

# %%
def skew(l):
    l1, l2, l3 = l
    return Matrix([
        [0, -l3, l2],
        [l3, 0, -l1],
        [-l2, l1, 0]
    ])

# %%
# define state variables
x, y, z, eta0, eps1, eps2, eps3, u, v, w, p, q, r = symbols('x y z et0 eps1 eps2 eps3 u v w p q r', real=True)
s = Matrix([x, y, z, eta0, eps1, eps2, eps3, u, v, w, p, q, r])

# position and orientation
eta = Matrix([x, y, z, eta0, eps1, eps2, eps3])
nu = Matrix([u, v, w, p, q, r])

# centre of gravity
xg, yg, zg = symbols('xg yg zg', real=True)
rg = Matrix([xg, yg, zg])

# centre of bouyancy
xb, yb, zb = symbols('xb yb zb', real=True)
rb = Matrix([xb, yb, zb])

# center of pressure
xcp, ycp, zcp = symbols('xcp ycp zcp', real=True)
rcp = Matrix([xcp, ycp, zcp])

# mass matrix
m = symbols('m', real=True, positive=True)
Ixx, Iyy, Izz = symbols('Ixx Iyy Izz')
I0 = diag(Ixx, Iyy, Izz)
M = BlockMatrix([
    [m*eye(3), -m*skew(rg)],
    [m*skew(rg), I0]
])
M = Matrix(M)
# M = simplify(M)

# Coriolis and centripetal matrix
nu1 = Matrix([u, v, w])
nu2 = Matrix([p, q, r])
crb = BlockMatrix([
    [zeros(3), -m*skew(nu1)-m*skew(nu2)*skew(rg)],
    [-m*skew(nu1)+m*skew(rg)*skew(nu2), -skew(I0*nu2)]
])
crb = Matrix(crb)
# crb = simplify(crb)

# damping matrix
Xuu, Yvv, Zww, Kpp, Mqq, Nrr = symbols(
    'Xuu Yvv Zww Kpp Mqq Nrr', real=True
)
D = Matrix([
    [Xuu*abs(u), 0, 0, 0, 0, 0],
    [0, Yvv*abs(v), 0, 0, 0, 0],
    [0, 0, Zww*abs(w), 0, 0, 0],
    [0, -zcp*Yvv*abs(v), ycp*Zww*abs(w), Kpp*abs(p), 0, 0],
    [zcp*Xuu*abs(u), 0, -xcp*Zww*abs(w), 0, Mqq*abs(q), 0],
    [-ycp*Xuu*abs(u), xcp*Yvv*abs(v), 0, 0, 0, Nrr*abs(r)]
])
# D = simplify(D)

# rotational transform between body and NED quaternions
Tq = Rational(1,2)*Matrix([
    [-eps1, -eps2, -eps3],
    [eta0, -eps3, eps2],
    [eps3, eta0, -eps1],
    [-eps2, eps1, eta0]
])
# Tq = simplify(Tq)

Rq = Matrix([
    [1-2*(eps2**2+eps3**2), 2*(eps1*eps2-eps3*eta0), 2*(eps1*eps3+eps2*eta0)],
    [2*(eps1*eps2+eps3*eta0), 1-2*(eps1**2+eps3**2), 2*(eps2*eps3-eps1*eta0)],
    [2*(eps1*eps3-eps2*eta0), 2*(eps2*eps3+eps1*eta0), 1-2*(eps1**2+eps2**2)]
])
Jeta = BlockMatrix([
    [Rq, zeros(3)],
    [zeros(4,3), Tq]
])
Jeta = Matrix(Jeta)
# Jeta = simplify(Jeta)

# bouyancy in quaternions
W, B = symbols('W B', real=True)
fg = Matrix([0, 0, W])
fb = Matrix([0, 0, -B])
Rqinv = Rq.inv()
geta = Matrix([
    Rqinv*(fg+fb),
    skew(rg)*Rqinv*fg + skew(rb)*Rqinv*fb
])
# geta = simplify(geta)

# %%
# print(cse(Jeta))

# %%
# thrust model
Kt0, Kt1 = symbols('Kt0 Kt1', real=True)
Kt = Matrix([Kt0, Kt1])
Qt0, Qt1 = symbols('Qt0 Qt1', real=True)
Qt = Matrix([Qt0, Qt1])

# control inputs
rpm0, rpm1 = symbols('rpm0 rpm1', real=True)
rpm = Matrix([rpm0, rpm1])
de, dr = symbols('de dr', real=True)
control_vector = Matrix([rpm0, rpm1, de, dr])

# control force vector
Ft = Kt.dot(rpm)
Mt = Qt.dot(rpm)

# coefficient for each element in cost function
tauc = Matrix([
    Ft*cos(de)*cos(dr),
    -Ft*sin(dr),
    Ft*sin(de)*cos(dr),
    Mt*cos(de)*cos(dr),
    -Mt*sin(dr),
    Mt*sin(de)*cos(dr)
])

# %%
etadot = Jeta*nu
nudot = M.inv()*(tauc - (crb + D)*nu - geta)

# %%
sdot = Matrix([
   etadot,
   nudot 
])

# %%
sdot
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   3                  2                           ⎞
# eps₃ + 4⋅eps₁⋅eps₃  + 4⋅eps₁⋅eps₃⋅et₀  - 2⋅eps₁⋅eps₃ - 2⋅eps₂⋅et₀⎠
# ──────────────────────────────────────────────────────────────────────────────
# 2         4         2     2         2    2         2         4         2    2
#   + 4⋅eps₂  + 8⋅eps₂ ⋅eps₃  + 4⋅eps₂ ⋅et₀  - 4⋅eps₂  + 4⋅eps₃  + 4⋅eps₃ ⋅et₀
# ──────────────────────────────────────────────────────────────────────────────
#        2   2        3   4        3   2   2        3   2   2            2   2
# x⋅Izz⋅m ⋅zg  + Ixx⋅m ⋅xg  + Ixx⋅m ⋅xg ⋅yg  + Ixx⋅m ⋅xg ⋅zg  - Iyy⋅Izz⋅m ⋅yg  -
#
#                  3                   3                  2              ⎞
# eps₁⋅et₀ + 4⋅eps₂ ⋅eps₃ + 4⋅eps₂⋅eps₃  + 4⋅eps₂⋅eps₃⋅et₀  - 2⋅eps₂⋅eps₃⎠
# ──────────────────────────────────────────────────────────────────────────────
#       2         4         2     2         2    2         2         4         2
# 4⋅eps₁  + 4⋅eps₂  + 8⋅eps₂ ⋅eps₃  + 4⋅eps₂ ⋅et₀  - 4⋅eps₂  + 4⋅eps₃  + 4⋅eps₃
# ──────────────────────────────────────────────────────────────────────────────
#           2   2        3   4        3   2   2        3   2   2            2
#  Ixx⋅Izz⋅m ⋅zg  + Ixx⋅m ⋅xg  + Ixx⋅m ⋅xg ⋅yg  + Ixx⋅m ⋅xg ⋅zg  - Iyy⋅Izz⋅m ⋅yg
#
#      2     2         2         4         2    2         2    ⎞
# ⋅eps₂ ⋅eps₃  - 2⋅eps₂  + 4⋅eps₃  + 4⋅eps₃ ⋅et₀  - 4⋅eps₃  + 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#          4         2     2         2    2         2         4         2    2
#  + 4⋅eps₂  + 8⋅eps₂ ⋅eps₃  + 4⋅eps₂ ⋅et₀  - 4⋅eps₂  + 4⋅eps₃  + 4⋅eps₃ ⋅et₀  -
# ──────────────────────────────────────────────────────────────────────────────
#       2   2        3   4        3   2   2        3   2   2            2   2
# ⋅Izz⋅m ⋅zg  + Ixx⋅m ⋅xg  + Ixx⋅m ⋅xg ⋅yg  + Ixx⋅m ⋅xg ⋅zg  - Iyy⋅Izz⋅m ⋅yg  -
#
#                3                   3                  2              ⎞
# s₁⋅et₀ + 4⋅eps₂ ⋅eps₃ + 4⋅eps₂⋅eps₃  + 4⋅eps₂⋅eps₃⋅et₀  - 2⋅eps₂⋅eps₃⎠
# ──────────────────────────────────────────────────────────────────────────────
#        2         4         2     2         2    2         2         4
#  4⋅eps₁  + 4⋅eps₂  + 8⋅eps₂ ⋅eps₃  + 4⋅eps₂ ⋅et₀  - 4⋅eps₂  + 4⋅eps₃  + 4⋅eps₃
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2                   3                  2                           ⎞
# ps₁⋅eps₂ ⋅eps₃ + 4⋅eps₁⋅eps₃  + 4⋅eps₁⋅eps₃⋅et₀  - 2⋅eps₁⋅eps₃ - 2⋅eps₂⋅et₀⎠
# ──────────────────────────────────────────────────────────────────────────────
#    2         2         4         2     2         2    2         2         4
# et₀  - 4⋅eps₁  + 4⋅eps₂  + 8⋅eps₂ ⋅eps₃  + 4⋅eps₂ ⋅et₀  - 4⋅eps₂  + 4⋅eps₃  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                   3                  2                           ⎞
# s₂ ⋅eps₃ + 4⋅eps₁⋅eps₃  + 4⋅eps₁⋅eps₃⋅et₀  - 2⋅eps₁⋅eps₃ - 2⋅eps₂⋅et₀⎠
# ──────────────────────────────────────────────────────────────────────────────
#        2         4         2     2         2    2         2         4
#  4⋅eps₁  + 4⋅eps₂  + 8⋅eps₂ ⋅eps₃  + 4⋅eps₂ ⋅et₀  - 4⋅eps₂  + 4⋅eps₃  + 4⋅eps₃
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                      ⎞
#                                                      ⎟ ⎛
# ───────────── + (Kt₀⋅rpm₀ + Kt₁⋅rpm₁)⋅cos(de)⋅cos(dr)⎟⋅⎝Ixx⋅Iyy⋅Izz - Ixx⋅Iyy⋅
#         2                                            ⎟
# - 4⋅eps₃  + 1                                        ⎠
# ──────────────────────────────────────────────────────────────────────────────
#           2   2        3   2   2        3   4        3   2   2        3   2
#  Iyy⋅Izz⋅m ⋅zg  + Iyy⋅m ⋅xg ⋅yg  + Iyy⋅m ⋅yg  + Iyy⋅m ⋅yg ⋅zg  + Izz⋅m ⋅xg ⋅zg
#
#                                                     ⎞
#                                                     ⎟ ⎛
# ─────────────────── + (-Kt₀⋅rpm₀ - Kt₁⋅rpm₁)⋅sin(dr)⎟⋅⎝Ixx⋅Iyy⋅Izz - Ixx⋅Iyy⋅m
#     2         2                                     ⎟
# ⋅et₀  - 4⋅eps₃  + 1                                 ⎠
# ──────────────────────────────────────────────────────────────────────────────
# 2            2   2        3   2   2        3   4        3   2   2        3   2
#   - Iyy⋅Izz⋅m ⋅zg  + Iyy⋅m ⋅xg ⋅yg  + Iyy⋅m ⋅yg  + Iyy⋅m ⋅yg ⋅zg  + Izz⋅m ⋅xg
#
#                                                     ⎞
#                                                     ⎟ ⎛
# ──────────── + (Kt₀⋅rpm₀ + Kt₁⋅rpm₁)⋅sin(de)⋅cos(dr)⎟⋅⎝Ixx⋅Iyy⋅Izz - Ixx⋅Iyy⋅m
#        2                                            ⎟
#  4⋅eps₃  + 1                                        ⎠
# ──────────────────────────────────────────────────────────────────────────────
#          2   2        3   2   2        3   4        3   2   2        3   2   2
# Iyy⋅Izz⋅m ⋅zg  + Iyy⋅m ⋅xg ⋅yg  + Iyy⋅m ⋅yg  + Iyy⋅m ⋅yg ⋅zg  + Izz⋅m ⋅xg ⋅zg
#
#                     ⎞
#                     ⎟
# ────────────────────⎟ - u⋅(-m⋅q⋅yg - m⋅r⋅zg) - v⋅(-Yvv⋅zcp⋅│v│ + m⋅p⋅yg + m⋅w)
# 2    2         2    ⎟
#  ⋅et₀  - 4⋅eps₃  + 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                           ⎞
#                           ⎟
# ──────────────────────────⎟ - u⋅(Xuu⋅zcp⋅│u│ + m⋅q⋅xg - m⋅w) - v⋅(-m⋅p⋅xg - m⋅
#       2    2         2    ⎟
# 4⋅eps₃ ⋅et₀  - 4⋅eps₃  + 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                     ⎞
#                     ⎟
# ────────────────────⎟ - u⋅(-Xuu⋅ycp⋅│u│ + m⋅r⋅xg + m⋅v) - v⋅(Yvv⋅xcp⋅│v│ + m⋅r
# 2    2         2    ⎟
#  ⋅et₀  - 4⋅eps₃  + 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     2               2        2   4               2               2        2
# m⋅xg  - Ixx⋅Izz⋅m⋅xg  + Ixx⋅m ⋅xg  - Iyy⋅Izz⋅m⋅yg  - Iyy⋅Izz⋅m⋅zg  + Iyy⋅m ⋅xg
#
#
# ──────────────────────────────────────────────────────────────────────────────
# 2        3   2   2        3   4
#   + Izz⋅m ⋅yg ⋅zg  + Izz⋅m ⋅zg
#
#
#    2               2               2        2   2   2               2        2
# ⋅yg  - Ixx⋅Izz⋅m⋅xg  - Ixx⋅Izz⋅m⋅zg  + Ixx⋅m ⋅xg ⋅yg  - Iyy⋅Izz⋅m⋅yg  + Iyy⋅m
#
#
# ──────────────────────────────────────────────────────────────────────────────
#    2        3   2   2        3   4
# ⋅zg  + Izz⋅m ⋅yg ⋅zg  + Izz⋅m ⋅zg
#
#
#    2               2               2        2   2   2               2        2
# ⋅xg  - Ixx⋅Iyy⋅m⋅yg  - Ixx⋅Izz⋅m⋅zg  + Ixx⋅m ⋅xg ⋅zg  - Iyy⋅Izz⋅m⋅zg  + Iyy⋅m
#
#
# ──────────────────────────────────────────────────────────────────────────────
#         3   2   2        3   4
#  + Izz⋅m ⋅yg ⋅zg  + Izz⋅m ⋅zg
#
#                                                                          ⎞
#                                                                          ⎟
#  - w⋅(Zww⋅ycp⋅│w│ + m⋅p⋅zg - m⋅v) + (Qt₀⋅rpm₀ + Qt₁⋅rpm₁)⋅cos(de)⋅cos(dr)⎟
#                                                                          ⎟
#                                                                          ⎠
# ──────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                         ⎞
#                                                                         ⎟
# r⋅zg) - w⋅(-Zww⋅xcp⋅│w│ + m⋅q⋅zg + m⋅u) + (-Qt₀⋅rpm₀ - Qt₁⋅rpm₁)⋅sin(dr)⎟
#                                                                         ⎟
#                                                                         ⎠
# ─────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                          ⎞
#                                                                          ⎟
# ⋅yg - m⋅u) - w⋅(-m⋅p⋅xg - m⋅q⋅yg) + (Qt₀⋅rpm₀ + Qt₁⋅rpm₁)⋅sin(de)⋅cos(dr)⎟
#                                                                          ⎟
#                                                                          ⎠
# ──────────────────────────────────────────────────────────────────────────
#
#
#
#                        ⎤
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
# 2   2        2   2   2⎞⎥
#  ⋅yg  + Izz⋅m ⋅xg ⋅zg ⎠⎥
#                        ⎥
#                        ⎥
# ───────────────────────⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#    4        2   2   2⎞ ⎥
# ⋅yg  + Izz⋅m ⋅yg ⋅zg ⎠ ⎥
#                        ⎥
#                        ⎥
# ────────────────────── ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#    2   2        2   4⎞ ⎥
# ⋅yg ⋅zg  + Izz⋅m ⋅zg ⎠ ⎥
#                        ⎥
#                        ⎥
# ────────────────────── ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎥
#                        ⎦
