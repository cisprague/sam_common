# %%
import sys; sys.path.append('../src/')
from fossen_euler import Fossen
import numpy as np, matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time

# %%
system = Fossen()
controller = lambda s: np.array([1000, 5, 0.1, 0.1])
# x, y, z, et0, eps1, eps2, eps3, u, v, w, p, q, r
state = np.array([0, 0, 0, np.pi, np.pi, np.pi, 0, 0, 0, 0, 0, 0], dtype=np.float32)
t0 = time.time()
t, x, u = system.propagate(state, controller, 0, 100, atol=1e-4, rtol=1e-4)
tf = time.time()
print(tf - t0)
# Out:
# 0.3570840358734131

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x[:,0], x[:,1], x[:,2], 'k.-')
plt.show()

# %%
fig, ax = plt.subplots(12)
for i in range(12):
    ax[i].plot(t, x[:,i], 'k.-')
plt.show()

# %%
np.apply_along_axis(controller, 1, x)
# Out:
# array([[1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
#        [1.e+03, 5.e+00, 1.e-01, 1.e-01],
# ...
